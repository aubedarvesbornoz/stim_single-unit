# %%
from pathlib import Path
import lfp_psd_cognitif as psd

# pour chaque session à inclure, besoin dans root_dir : 
    # du TRC + TRC_corrected.txt + TRC_re-shifted_(loca)_COG.txt
    # ou bien : du TRC + TRC.txt + TRC_shifted.txt + TRC_re-shifted.txt + TRC_re-shifted_(loca)_COG.txt

# et besoin de renseigner les bad channels dans root_dir/TRC_bad_channels.xlsx (d'après inspection visuelle du TRC, par ex. sur Brainstorm)
    
cfg = psd.PSDConfig(
    root_dir=Path('/home/aube/Documents/article_neuronal_stimic/effets_cog'),
    output_dir=Path('/home/aube/Documents/article_neuronal_stimic/effets_cog/PSD_cognitif'),
    pre_length=5.0, # durée baseline pré-EBS
    post_length=2.0, # durée post-EBS
    epsilon=0.1, # pour s'écarter de l'artefact du (premier ou dernier) pulse de stim
    fmin=1, # fréquence min
    fmax=150, # fréquence max
)

all_psd, grand = psd.run_psd_pipeline(cfg)
psd.plot_grand_average_psd(grand, cfg)
print('end')
# Out:
# [SESSION] P101_DC54_stim4
# [ERROR] P101_DC54_stim4: FileNotFoundError: Aucun fichier COG trouvé pour P101_DC54_stim4
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 21
#      10 cfg = psd.PSDConfig(
#      11     root_dir=Path('/home/aube/Documents/article_neuronal_stimic/effets_cog'),
#      12     output_dir=Path('/home/aube/Documents/article_neuronal_stimic/effets_cog/PSD_cognitif'),
#    (...)     17     fmax=150, # fréquence max
#      18 )
#      20 all_psd, grand = psd.run_psd_pipeline(cfg)
# ---> 21 psd.plot_grand_average_psd(grand, cfg)
#      22 print('end')
#
# File ~/Documents/GitHub/stim_single-unit/4_LFP_frequencies/lfp_psd_cognitif.py:651, in plot_grand_average_psd(df, cfg, yscale, show_sem, title, session)
#     643 styles = {
#     644     "pre-EBS": {"label": "pre-EBS", "color": "gray"},
#     645     "post-EBS_cog": {"label": "post-EBS cog", "color": "green"},
#     646     "post-EBS_ctrl": {"label": "post-EBS contrôle", "color": "blue"},
#     647     "post-EBS_neg": {"label": "post-EBS négatif", "color": "red"},
#     648 }
#     650 for cond, style in styles.items():
# --> 651     sub = df.loc[df["condition"].eq(cond)].sort_values("freq_hz")
#     652     if len(sub) == 0:
#     653         continue
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File /var/data/python/lib/python3.13/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'condition'
