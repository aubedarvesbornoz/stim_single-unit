# %%
from pathlib import Path
import lfp_psd_cognitif as psd

# pour chaque session à inclure, besoin dans root_dir : 
    # du TRC + TRC_corrected.txt + TRC_re-shifted_(loca)_COG.txt
    # ou bien : du TRC + TRC.txt + TRC_shifted.txt + TRC_re-shifted.txt + TRC_re-shifted_(loca)_COG.txt

# et besoin de renseigner les bad channels dans root_dir/TRC_bad_channels.xlsx (d'après inspection visuelle du TRC, par ex. sur Brainstorm)
    
cfg = psd.PSDConfig(
    root_dir=Path('/home/aube/Documents/article_neuronal_stimic/effets_cog/LFP'),
    output_dir=Path('/home/aube/Documents/article_neuronal_stimic/effets_cog/PSD_cognitif'),
    pre_length=5.0, # durée baseline pré-EBS
    post_length=2.0, # durée post-EBS
    epsilon=0.1, # pour s'écarter de l'artefact du (premier ou dernier) pulse de stim
    fmin=1, # fréquence min
    fmax=150, # fréquence max
)

all_psd, grand, cog_local = psd.run_psd_pipeline(cfg)
psd.plot_grand_average_psd(grand, cfg)
print('end')
# Out:
# in run
# ['P119_FM71_stim4']
# [INFO] P119_FM71_stim4: PSD moyenne session déjà créée, skip
# [               session     condition epoch_kind  trial_local_index  \
# 0      P119_FM71_stim4       pre-EBS        pre                  0
# 1      P119_FM71_stim4       pre-EBS        pre                  0
# 2      P119_FM71_stim4       pre-EBS        pre                  0
# 3      P119_FM71_stim4       pre-EBS        pre                  0
# 4      P119_FM71_stim4       pre-EBS        pre                  0
# ...                ...           ...        ...                ...
# 76495  P119_FM71_stim4  post-EBS_neg       post                  1
# 76496  P119_FM71_stim4  post-EBS_neg       post                  1
# 76497  P119_FM71_stim4  post-EBS_neg       post                  1
# 76498  P119_FM71_stim4  post-EBS_neg       post                  1
# 76499  P119_FM71_stim4  post-EBS_neg       post                  1
#
#        stim_index                    label_stim group_label         lobe  \
# 0              15  CPp1-CPp21.5mA50.0Hz1025µsec    controle  L Cingulate
# 1              15  CPp1-CPp21.5mA50.0Hz1025µsec    controle  L Cingulate
# 2              15  CPp1-CPp21.5mA50.0Hz1025µsec    controle  L Cingulate
# 3              15  CPp1-CPp21.5mA50.0Hz1025µsec    controle  L Cingulate
# 4              15  CPp1-CPp21.5mA50.0Hz1025µsec    controle  L Cingulate
# ...           ...                           ...         ...          ...
# 76495          22  GCp1-GCp22.2mA50.0Hz1025µsec     negatif  L Cingulate
# 76496          22  GCp1-GCp22.2mA50.0Hz1025µsec     negatif  L Cingulate
# 76497          22  GCp1-GCp22.2mA50.0Hz1025µsec     negatif  L Cingulate
# 76498          22  GCp1-GCp22.2mA50.0Hz1025µsec     negatif  L Cingulate
# 76499          22  GCp1-GCp22.2mA50.0Hz1025µsec     negatif  L Cingulate
#
#       bp_channel  freq_hz     psd_v2_hz stim_shaft stim_bipolar_label  \
# 0      TPp1-TPp2      2.0  8.178621e-10        CPp               None
# 1      TPp1-TPp2      4.0  2.197717e-10        CPp               None
# 2      TPp1-TPp2      6.0  1.642655e-11        CPp               None
# 3      TPp1-TPp2      8.0  6.478607e-12        CPp               None
# 4      TPp1-TPp2     10.0  4.827969e-12        CPp               None
# ...          ...      ...           ...        ...                ...
# 76495    CP5-CP6    142.0  1.352035e-14        GCp               None
# 76496    CP5-CP6    144.0  1.876316e-14        GCp               None
# 76497    CP5-CP6    146.0  2.130317e-14        GCp               None
# 76498    CP5-CP6    148.0  1.330847e-14        GCp               None
# 76499    CP5-CP6    150.0  9.367218e-15        GCp               None
#
#       stim_contact_pair       macro_part
# 0                   1-2  P119_FM71_stim4
# 1                   1-2  P119_FM71_stim4
# 2                   1-2  P119_FM71_stim4
# 3                   1-2  P119_FM71_stim4
# 4                   1-2  P119_FM71_stim4
# ...                 ...              ...
# 76495               1-2  P119_FM71_stim4
# 76496               1-2  P119_FM71_stim4
# 76497               1-2  P119_FM71_stim4
# 76498               1-2  P119_FM71_stim4
# 76499               1-2  P119_FM71_stim4
#
# [76500 rows x 15 columns]]
# in compue gd av, psd long= (76500, 15)
#                session     condition epoch_kind  trial_local_index  \
# 0      P119_FM71_stim4       pre-EBS        pre                  0
# 1      P119_FM71_stim4       pre-EBS        pre                  0
# 2      P119_FM71_stim4       pre-EBS        pre                  0
# 3      P119_FM71_stim4       pre-EBS        pre                  0
# 4      P119_FM71_stim4       pre-EBS        pre                  0
# ...                ...           ...        ...                ...
# 76495  P119_FM71_stim4  post-EBS_neg       post                  1
# 76496  P119_FM71_stim4  post-EBS_neg       post                  1
# 76497  P119_FM71_stim4  post-EBS_neg       post                  1
# 76498  P119_FM71_stim4  post-EBS_neg       post                  1
# 76499  P119_FM71_stim4  post-EBS_neg       post                  1
#
#        stim_index                    label_stim group_label         lobe  \
# 0              15  CPp1-CPp21.5mA50.0Hz1025µsec    controle  L Cingulate
# 1              15  CPp1-CPp21.5mA50.0Hz1025µsec    controle  L Cingulate
# 2              15  CPp1-CPp21.5mA50.0Hz1025µsec    controle  L Cingulate
# 3              15  CPp1-CPp21.5mA50.0Hz1025µsec    controle  L Cingulate
# 4              15  CPp1-CPp21.5mA50.0Hz1025µsec    controle  L Cingulate
# ...           ...                           ...         ...          ...
# 76495          22  GCp1-GCp22.2mA50.0Hz1025µsec     negatif  L Cingulate
# 76496          22  GCp1-GCp22.2mA50.0Hz1025µsec     negatif  L Cingulate
# 76497          22  GCp1-GCp22.2mA50.0Hz1025µsec     negatif  L Cingulate
# 76498          22  GCp1-GCp22.2mA50.0Hz1025µsec     negatif  L Cingulate
# 76499          22  GCp1-GCp22.2mA50.0Hz1025µsec     negatif  L Cingulate
#
#       bp_channel  freq_hz     psd_v2_hz stim_shaft stim_bipolar_label  \
# 0      TPp1-TPp2      2.0  8.178621e-10        CPp               None
# 1      TPp1-TPp2      4.0  2.197717e-10        CPp               None
# 2      TPp1-TPp2      6.0  1.642655e-11        CPp               None
# 3      TPp1-TPp2      8.0  6.478607e-12        CPp               None
# 4      TPp1-TPp2     10.0  4.827969e-12        CPp               None
# ...          ...      ...           ...        ...                ...
# 76495    CP5-CP6    142.0  1.352035e-14        GCp               None
# 76496    CP5-CP6    144.0  1.876316e-14        GCp               None
# 76497    CP5-CP6    146.0  2.130317e-14        GCp               None
# 76498    CP5-CP6    148.0  1.330847e-14        GCp               None
# 76499    CP5-CP6    150.0  9.367218e-15        GCp               None
#
#       stim_contact_pair       macro_part
# 0                   1-2  P119_FM71_stim4
# 1                   1-2  P119_FM71_stim4
# 2                   1-2  P119_FM71_stim4
# 3                   1-2  P119_FM71_stim4
# 4                   1-2  P119_FM71_stim4
# ...                 ...              ...
# 76495               1-2  P119_FM71_stim4
# 76496               1-2  P119_FM71_stim4
# 76497               1-2  P119_FM71_stim4
# 76498               1-2  P119_FM71_stim4
# 76499               1-2  P119_FM71_stim4
#
# [76500 rows x 15 columns]
# in compue gd av, psd long= (38250, 16)
#                session             condition epoch_kind  trial_local_index  \
# 0      P119_FM71_stim4               pre-EBS        pre                  1
# 1      P119_FM71_stim4               pre-EBS        pre                  1
# 2      P119_FM71_stim4               pre-EBS        pre                  1
# 3      P119_FM71_stim4               pre-EBS        pre                  1
# 4      P119_FM71_stim4               pre-EBS        pre                  1
# ...                ...                   ...        ...                ...
# 38245  P119_FM71_stim4  post-EBS_cog_distant       post                  2
# 38246  P119_FM71_stim4  post-EBS_cog_distant       post                  2
# 38247  P119_FM71_stim4  post-EBS_cog_distant       post                  2
# 38248  P119_FM71_stim4  post-EBS_cog_distant       post                  2
# 38249  P119_FM71_stim4  post-EBS_cog_distant       post                  2
#
#        stim_index                    label_stim group_label         lobe  \
# 0              16  GCp1-GCp21.8mA50.0Hz1025µsec        cog+  L Cingulate
# 1              16  GCp1-GCp21.8mA50.0Hz1025µsec        cog+  L Cingulate
# 2              16  GCp1-GCp21.8mA50.0Hz1025µsec        cog+  L Cingulate
# 3              16  GCp1-GCp21.8mA50.0Hz1025µsec        cog+  L Cingulate
# 4              16  GCp1-GCp21.8mA50.0Hz1025µsec        cog+  L Cingulate
# ...           ...                           ...         ...          ...
# 38245          23  CPp2-CPp32.2mA50.0Hz1025µsec        cog+  L Cingulate
# 38246          23  CPp2-CPp32.2mA50.0Hz1025µsec        cog+  L Cingulate
# 38247          23  CPp2-CPp32.2mA50.0Hz1025µsec        cog+  L Cingulate
# 38248          23  CPp2-CPp32.2mA50.0Hz1025µsec        cog+  L Cingulate
# 38249          23  CPp2-CPp32.2mA50.0Hz1025µsec        cog+  L Cingulate
#
#       bp_channel  freq_hz     psd_v2_hz stim_shaft stim_bipolar_label  \
# 0      TPp1-TPp2      2.0  4.150836e-10        GCp               None
# 1      TPp1-TPp2      4.0  1.644551e-10        GCp               None
# 2      TPp1-TPp2      6.0  6.206806e-11        GCp               None
# 3      TPp1-TPp2      8.0  1.219359e-11        GCp               None
# 4      TPp1-TPp2     10.0  5.713516e-12        GCp               None
# ...          ...      ...           ...        ...                ...
# 38245    CP5-CP6    142.0  2.701611e-14        CPp               None
# 38246    CP5-CP6    144.0  2.716539e-14        CPp               None
# 38247    CP5-CP6    146.0  1.562304e-14        CPp               None
# 38248    CP5-CP6    148.0  1.557599e-14        CPp               None
# 38249    CP5-CP6    150.0  3.697548e-14        CPp               None
#
#       stim_contact_pair       macro_part local_distant
# 0                   1-2  P119_FM71_stim4       distant
# 1                   1-2  P119_FM71_stim4       distant
# 2                   1-2  P119_FM71_stim4       distant
# 3                   1-2  P119_FM71_stim4       distant
# 4                   1-2  P119_FM71_stim4       distant
# ...                 ...              ...           ...
# 38245               2-3  P119_FM71_stim4       distant
# 38246               2-3  P119_FM71_stim4       distant
# 38247               2-3  P119_FM71_stim4       distant
# 38248               2-3  P119_FM71_stim4       distant
# 38249               2-3  P119_FM71_stim4       distant
#
# [38250 rows x 16 columns]
# in compue gd av, psd long= (38250, 16)
#                session             condition epoch_kind  trial_local_index  \
# 0      P119_FM71_stim4               pre-EBS        pre                  1
# 1      P119_FM71_stim4               pre-EBS        pre                  1
# 2      P119_FM71_stim4               pre-EBS        pre                  1
# 3      P119_FM71_stim4               pre-EBS        pre                  1
# 4      P119_FM71_stim4               pre-EBS        pre                  1
# ...                ...                   ...        ...                ...
# 38245  P119_FM71_stim4  post-EBS_cog_distant       post                  2
# 38246  P119_FM71_stim4  post-EBS_cog_distant       post                  2
# 38247  P119_FM71_stim4  post-EBS_cog_distant       post                  2
# 38248  P119_FM71_stim4  post-EBS_cog_distant       post                  2
# 38249  P119_FM71_stim4  post-EBS_cog_distant       post                  2
#
#        stim_index                    label_stim group_label         lobe  \
# 0              16  GCp1-GCp21.8mA50.0Hz1025µsec        cog+  L Cingulate
# 1              16  GCp1-GCp21.8mA50.0Hz1025µsec        cog+  L Cingulate
# 2              16  GCp1-GCp21.8mA50.0Hz1025µsec        cog+  L Cingulate
# 3              16  GCp1-GCp21.8mA50.0Hz1025µsec        cog+  L Cingulate
# 4              16  GCp1-GCp21.8mA50.0Hz1025µsec        cog+  L Cingulate
# ...           ...                           ...         ...          ...
# 38245          23  CPp2-CPp32.2mA50.0Hz1025µsec        cog+  L Cingulate
# 38246          23  CPp2-CPp32.2mA50.0Hz1025µsec        cog+  L Cingulate
# 38247          23  CPp2-CPp32.2mA50.0Hz1025µsec        cog+  L Cingulate
# 38248          23  CPp2-CPp32.2mA50.0Hz1025µsec        cog+  L Cingulate
# 38249          23  CPp2-CPp32.2mA50.0Hz1025µsec        cog+  L Cingulate
#
#       bp_channel  freq_hz     psd_v2_hz stim_shaft stim_bipolar_label  \
# 0      TPp1-TPp2      2.0  4.150836e-10        GCp               None
# 1      TPp1-TPp2      4.0  1.644551e-10        GCp               None
# 2      TPp1-TPp2      6.0  6.206806e-11        GCp               None
# 3      TPp1-TPp2      8.0  1.219359e-11        GCp               None
# 4      TPp1-TPp2     10.0  5.713516e-12        GCp               None
# ...          ...      ...           ...        ...                ...
# 38245    CP5-CP6    142.0  2.701611e-14        CPp               None
# 38246    CP5-CP6    144.0  2.716539e-14        CPp               None
# 38247    CP5-CP6    146.0  1.562304e-14        CPp               None
# 38248    CP5-CP6    148.0  1.557599e-14        CPp               None
# 38249    CP5-CP6    150.0  3.697548e-14        CPp               None
#
#       stim_contact_pair       macro_part local_distant
# 0                   1-2  P119_FM71_stim4       distant
# 1                   1-2  P119_FM71_stim4       distant
# 2                   1-2  P119_FM71_stim4       distant
# 3                   1-2  P119_FM71_stim4       distant
# 4                   1-2  P119_FM71_stim4       distant
# ...                 ...              ...           ...
# 38245               2-3  P119_FM71_stim4       distant
# 38246               2-3  P119_FM71_stim4       distant
# 38247               2-3  P119_FM71_stim4       distant
# 38248               2-3  P119_FM71_stim4       distant
# 38249               2-3  P119_FM71_stim4       distant
#
# [38250 rows x 16 columns]
# end

# %%
grand
# Out:
#         condition  freq_hz  mean_psd_v2_hz  sd_psd_v2_hz  n_units  \
# 0    post-EBS_cog      2.0    1.522531e-10  4.043766e-10      255
# 1    post-EBS_cog      4.0    8.730989e-11  2.275179e-10      255
# 2    post-EBS_cog      6.0    3.636129e-11  8.734951e-11      255
# 3    post-EBS_cog      8.0    1.954616e-11  5.900258e-11      255
# 4    post-EBS_cog     10.0    1.049251e-11  2.421789e-11      255
# ..            ...      ...             ...           ...      ...
# 295       pre-EBS    142.0    3.005371e-14  2.123831e-13      510
# 296       pre-EBS    144.0    2.590100e-14  1.503018e-13      510
# 297       pre-EBS    146.0    2.419047e-14  1.278152e-13      510
# 298       pre-EBS    148.0    2.720268e-14  1.644212e-13      510
# 299       pre-EBS    150.0    3.151431e-14  1.504642e-13      510
#
#      sem_psd_v2_hz
# 0     2.532305e-11
# 1     1.424772e-11
# 2     5.470039e-12
# 3     3.694885e-12
# 4     1.516583e-12
# ..             ...
# 295   9.404480e-15
# 296   6.655478e-15
# 297   5.659750e-15
# 298   7.280694e-15
# 299   6.662668e-15
#
# [300 rows x 6 columns]
